# %% [markdown]
# #  Prediction Using Descision Tree Algorithm

# %% [markdown]
# ***LGMVIP-DATASCIENCE OCTOBER INTERNSHIP INTERMEDIATE LEVEL TASK***

# %% [markdown]
# ***By Chirag Verma***

# %%
#Importing all libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
from sklearn import tree

# %%
#import dataset
data=load_iris()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#checking for null values
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
#No.of rows and columns
df.shape
# Out:
# (150, 5)

# %%
#showing only target data[Dependent variable]
print(df['target'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int32

# %%
#spliting data
fc=[x for x in df.columns if x!="target"]
x=df[fc]
y=df["target"]
X_train ,X_test,Y_train,Y_test=train_test_split(x,y,random_state=100,test_size=0.30)

# %%
#dispaly data
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (105, 4)
# (45, 4)
# (105,)
# (45,)

# %%
#building decision tree model

modell=DecisionTreeClassifier()

# %%
#predicting values
Y_pred=modell.fit(X_test,Y_test)

# %%
Y_pred=modell.predict(X_test)

# %%
#comparision
data2=pd.DataFrame({"Actual":Y_test,"Predicted":Y_pred})
data2.head()
# Out:
#      Actual                 Predicted
# 128       2  DecisionTreeClassifier()
# 11        0  DecisionTreeClassifier()
# 118       2  DecisionTreeClassifier()
# 15        0  DecisionTreeClassifier()
# 123       2  DecisionTreeClassifier()

# %%
#testing the accuracy of model prediction
accuracy_score(Y_test,Y_pred)*100
# Out:
# 100.0

# %%
#plotting
f_n=["Sepal length", "Sepal width", "Petal length", "Petal width"]
c_n=["Setosa","Versicolor","Virginica"]
plot_tree(modell,feature_names=f_n,class_names=c_n,filled=True)
# Out:
# [Text(167.4, 195.696, 'Petal length <= 2.7\ngini = 0.654\nsamples = 45\nvalue = [16, 11, 18]\nclass = Virginica'),
#  Text(111.60000000000001, 152.208, 'gini = 0.0\nsamples = 16\nvalue = [16, 0, 0]\nclass = Setosa'),
#  Text(223.20000000000002, 152.208, 'Petal width <= 1.75\ngini = 0.471\nsamples = 29\nvalue = [0, 11, 18]\nclass = Virginica'),
#  Text(167.4, 108.72, 'Sepal width <= 2.3\ngini = 0.153\nsamples = 12\nvalue = [0, 11, 1]\nclass = Versicolor'),
#  Text(111.60000000000001, 65.232, 'Petal length <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = Versicolor'),
#  Text(55.800000000000004, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(167.4, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(223.20000000000002, 65.232, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]\nclass = Versicolor'),
#  Text(279.0, 108.72, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17]\nclass = Virginica')]

# %%
modelx=DecisionTreeClassifier().fit(x,y)

# %%
plt.figure(figsize=(20,15))
tree=tree.plot_tree(modelx,feature_names=f_n,class_names=c_n,filled=True)
